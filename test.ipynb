# %%
import pandas as pd

columns = ['userid', 'timestamp', 'artid', 'artname', 'traid', 'traname']

df_lastfm = pd.read_csv(
        'data/lastfm-dataset-1K/userid-timestamp-artid-artname-traid-traname.tsv', 
        sep='\t', 
        on_bad_lines='skip',
        names=columns, 
        header=None,
        nrows=100000 # full load is 19 millions rows, cap it to 100,000
    )
df_lastfm
# Out:
#    user_000001  2009-05-04T23:08:57Z  f1b1cf71-bd35-4e99-8624-24a6e15f133a  \
# 0  user_000001  2009-05-04T13:54:10Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 1  user_000001  2009-05-04T13:52:04Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2  user_000001  2009-05-04T13:42:52Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3  user_000001  2009-05-04T13:42:11Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4  user_000001  2009-05-04T13:38:31Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 5  user_000001  2009-05-04T13:33:28Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 6  user_000001  2009-05-04T13:23:45Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 7  user_000001  2009-05-04T13:19:22Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 8  user_000001  2009-05-04T13:13:38Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 9  user_000001  2009-05-04T13:06:09Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
#
#   Deep Dish                            Unnamed: 4  \
# 0      坂本龍一                                   NaN
# 1      坂本龍一                                   NaN
# 2      坂本龍一                                   NaN
# 3      坂本龍一                                   NaN
# 4      坂本龍一                                   NaN
# 5      坂本龍一                                   NaN
# 6      坂本龍一                                   NaN
# 7      坂本龍一                                   NaN
# 8      坂本龍一                                   NaN
# 9      坂本龍一  f7c1f8f8-b935-45ed-8fc8-7def69d92a10
#
#   Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 0          Composition 0919 (Live_2009_4_15)
# 1                       Mc2 (Live_2009_4_15)
# 2                    Hibari (Live_2009_4_15)
# 3                       Mc1 (Live_2009_4_15)
# 4               To Stanford (Live_2009_4_15)
# 5             Improvisation (Live_2009_4_15)
# 6                   Glacier (Live_2009_4_15)
# 7                 Parolibre (Live_2009_4_15)
# 8            Bibo No Aozora (Live_2009_4_15)
# 9                   The Last Emperor (Theme)
